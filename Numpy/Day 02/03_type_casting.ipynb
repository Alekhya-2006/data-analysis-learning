# %%
import numpy as np

# %%
arr = np.array([[1, 3], [2, 4], [5, 7], [6, 8]])
print(arr, arr.dtype)

float_arr = arr.astype(np.float64)
print(float_arr, float_arr.dtype)
# Out:
# [[1 3]
#  [2 4]
#  [5 7]
#  [6 8]] int64
# [[1. 3.]
#  [2. 4.]
#  [5. 7.]
#  [6. 8.]] float64
