# %%
import numpy as np

# %%
# indexing
arr = np.array([1, 2, 3, 4, 5])

print(arr[0])
print(arr[-1])

arr2D = np.array([[1, 2, 3], [4, 5, 6]])
print(arr2D[0][2])
print(arr2D[1][1])
# Out:
# 1
# 5
# 3
# 5
