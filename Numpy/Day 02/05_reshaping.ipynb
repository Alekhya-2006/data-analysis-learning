# %%
import numpy as np

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(arr, arr.shape)

reshaped = arr.reshape((3, 2)) # reshape
print(reshaped, reshaped.shape)

flattened = arr.flatten() # 2D --> 1D
print(flattened, flattened.shape)
# Out:
# [[1 2 3]
#  [4 5 6]] (2, 3)
# [[1 2]
#  [3 4]
#  [5 6]] (3, 2)
# [1 2 3 4 5 6] (6,)
