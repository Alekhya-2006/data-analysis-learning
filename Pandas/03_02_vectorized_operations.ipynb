# %%
import pandas as pd

# %%
# In series, Vectorized Operations can be performed

s1 = pd.Series([1, 3, 5, 7, 9])
s2 = pd.Series([2, 4, 6, 8, 10])

print(s1 + s2)
# Out:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    19
# dtype: int64
