# %%
import pandas as pd

# %%
# Handle Duplicates
df = pd.read_csv("ipl_matches_2026.csv")

cities = df["city"]
unique_cities = cities.drop_duplicates()

# %%
unique_cities
# Out:
# 0          Bengaluru
# 1             Mumbai
# 2           Guwahati
# 3     New Chandigarh
# 4            Lucknow
# 5            Kolkata
# 6            Chennai
# 7          Ahmedabad
# 8              Delhi
# 9          Hyderabad
# 35            Jaipur
# 53            Raipur
# 54        Dharamsala
# Name: city, dtype: object
