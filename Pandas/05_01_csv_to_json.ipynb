# %%
import pandas as pd

# %%
# Read CSV file
df = pd.read_csv("ipl_matches_2026.csv")

# Convert to JSON
df.to_json("ipl_matches_2026.json", orient="records", indent=4)

print("JSON file created successfully!")
# Out:
# JSON file created successfully!

# %%
# Veriify the json
import json

with open("ipl_matches_2026.json", "r") as f:
    data = json.load(f)

print("successfully loaded")
# Out:
# successfully loaded
