# %%
import pandas as pd

# %%
df = pd.read_csv("ipl_matches_2026.csv")

# filtering data
df[ (df["team1_runs"] > 200) & (df["toss_decision"] == "bat")]

df[ (df["team1_runs"] > 200) & (df["toss_decision"] == "bat")][["team1", "team1_runs"]]

high_runs = df[ df["team1_runs"] > 250] [["team1", "team1_runs"]]
high_runs.iloc[0]

# high_runs.loc[0] # error because there is no label in the name of 0 in high_runs
# Out:
# team1         Punjab Kings
# team1_runs             254
# Name: 27, dtype: object
