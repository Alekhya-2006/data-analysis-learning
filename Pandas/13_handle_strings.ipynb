# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv")

df["gender"].str.upper()
df["name"].str.split(" ")

df["country"].str.contains("india", case = False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7       NaN
# 8     False
# 9     False
# 10    False
# Name: country, dtype: object
