# %%
import pandas as pd

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series([10, 20, 30, 40, 50])
print(s1 + s2)

# mutable values
s1[0] = 100
print(s1)

# immutable size
changed_s1 = s1.drop(0) # It doesn't modify s1. It create new series

print(s1)
print(changed_s1)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64
# 0    100
# 1      2
# 2      3
# 3      4
# 4      5
# dtype: int64
# 0    100
# 1      2
# 2      3
# 3      4
# 4      5
# dtype: int64
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
